# %%
import os
from termcolor import colored

directory='C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/'

i=1
j=1;
    
for subdir, dirs, files in os.walk(directory):
    for file in files:
#         print (file)
        if '.inc.as' in file:
            print(i,') ',subdir,'\n\n',colored(file,'blue'))
            i+=1
            j=1
            with open(os.path.join(subdir,file), "r") as fileHandler:  
                # Read next line
                for line in fileHandler:
                    if 'public function' in line:
                        print(j,']', line)
                        j+=1
                   
            
            
            print('-------------------------------------------------')
#         if file.contains( '.as'):
#             print (file)
# Out:
# 1 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/AlternativePostingTeam
#
#  AlternativePostingTeam.inc.as
# 1 ] public function get GridIcon():Object {
#
# -------------------------------------------------
# 2 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/ContractType
#
#  ContractType.inc.as
# -------------------------------------------------
# 3 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/EnterpriseWorkContract
#
#  EnterpriseWorkContract.inc.as
# 1 ] public function get GridIcon():Object {
#
# 2 ] public function get ContractedTimePerWeekConversionMultiplier():Number {
#
# 3 ] public function get ContractedTimeBasisCaption():String{
#
# 4 ] public function get IsBank():Boolean {
#
# 5 ] public function get IsAgency():Boolean {
#
# 6 ] public function get IsBankOrAgency():Boolean {
#
# -------------------------------------------------
# 4 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/GlobalWorkContract
#
#  GlobalWorkContract.inc.as
# -------------------------------------------------
# 5 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/GlobalWorkingRestrictionSet
#
#  AddGlobalWorkingRestrictionSet.inc.as
# 1 ] override public function CompleteConstruction():void {
#
# 2 ] override public function AddAdditionalCommandXml(commandXml:XML):void {
#
# -------------------------------------------------
# 6 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/GlobalWorkingRestrictionSet
#
#  GlobalWorkingRestrictionSet.inc.as
# 1 ] public function get GridIcon():Object {
#
# 2 ] override public function DefaultLeaveTime(onDate:Date,dataContext:DataContext):Number{
#
# -------------------------------------------------
# 7 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/GlobalWorkingRestrictionSet
#
#  UpdateGlobalWorkingRestrictionSet.inc.as
# 1 ] override public function CompleteConstruction():void {
#
# 2 ] override public function AddAdditionalCommandXml(commandXml:XML):void {
#
# -------------------------------------------------
# 8 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Grade
#
#  Grade.inc.as
# 1 ] public function get GridIcon():Object {
#
# 2 ] public function get DisplayName():String {
#
# 3 ] public function NameAndCode():String {
#
# 4 ] public function get NegotiatedRatesCanApply():Boolean {
#
# 5 ] public function get IsInterfaceBankStaff():Boolean{
#
# 6 ] public function GetNegotiatedRatesForGrade(context:DataContext):ArrayCollection{
#
# 7 ] public function UserHasAccessToImportReferenceData():Boolean{
#
# 8 ] public function UserHasAccessToExportReferenceData():Boolean{
#
# -------------------------------------------------
# 9 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/GradeType
#
#  GradeType.inc.as
# 1 ] public function get GridIcon():Object {
#
# 2 ] public function get WTEMins():Number {
#
# 3 ] public function IsNHSp():Boolean {
#
# 4 ] public function UserHasAccessToImportReferenceData():Boolean{
#
# 5 ] public function UserHasAccessToExportReferenceData():Boolean{
#
# -------------------------------------------------
# 10 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/GradeTypeCategory
#
#  GradeTypeCategory.inc.as
# 1 ] public function get GridIcon():Object {
#
# 2 ] public function IsNHSp():Boolean {
#
# -------------------------------------------------
# 11 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/GradeWorkContract
#
#  GradeWorkContract.inc.as
# 1 ] public function get GridIcon():Object {
#
# 2 ] public function get OccGroup():Domain.Employment.OccGroup.OccGroup {return Grade.OccGroup}
#
# 3 ] public function get EnterpriseWorkContractName():String {
#
# 4 ] public function get WTEMins():Number {
#
# 5 ] public function get IsBankOrAgency():Boolean {
#
# 6 ] public function IsValidDayForWorkerType(dataContext:DataContext, day:Date, isPublicHolidaysInDateRange:Boolean):Boolean {
#
# -------------------------------------------------
# 12 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/OccGroup
#
#  OccGroup.inc.as
# 1 ] public function get GridIcon():Object {
#
# 2 ] public function get StandardIcon():Object {
#
# 3 ] public function get FuturePersonIcon():Object {
#
# 4 ] public function get ClosedPersonIcon():Object {
#
# 5 ] public function get PostingHasAdditionalContractIcon():Object {
#
# 6 ] public function get BankIcon():Object {
#
# 7 ] public function get AgencyIcon():Object {
#
# 8 ] public function get LocalBankIcon():Object {
#
# 9 ] public function get LocalAgencyIcon():Object {
#
# 10 ] public function get BankFutureIcon():Object {
#
# 11 ] public function get AgencyFutureIcon():Object {
#
# 12 ] public function get LocalBankFutureIcon():Object {
#
# 13 ] public function get LocalAgencyFutureIcon():Object {
#
# 14 ] public function get DetachedPersonIcon():Object {
#
# 15 ] public function get PersonCanTakeChargeIcon():Object {
#
# 16 ] public function get TraineeIcon():Object {
#
# 17 ] public function get CloudStaffPersonIcon():Object {
#
# -------------------------------------------------
# 13 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/OrgUnitPersonAttachment
#
#  AddOrgUnitPersonAttachment.inc.as
# 1 ] override public function CompleteConstruction():void {
#
# 2 ] override public function AddAdditionalCommandXml(commandXml:XML):void {
#
# 3 ] public function get CanAddOrgUnitPersonAttachment():Boolean {
#
# -------------------------------------------------
# 14 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/OrgUnitPersonAttachment
#
#  OrgUnitPersonAttachment.inc.as
# 1 ] public function get AttachNonPostedPeopleToUnitIsEnabled():Boolean {
#
# 2 ] public function get CanAddEditOrgUnitPersonAttachmentFromPerson():Boolean {
#
# 3 ] public function get CanAddEditOrgUnitPersonAttachmentFromUnit():Boolean {
#
# 4 ] public function get UserCanFinalisePerson():Boolean {
#
# -------------------------------------------------
# 15 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/PatternAssignmentsForTeam
#
#  PatternAssignmentsForTeam.inc.as
# -------------------------------------------------
# 16 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/PersonEmployment
#
#  PersonEmployment.inc.as
# -------------------------------------------------
# 17 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/PersonWorkContract
#
#  PersonWorkContract.inc.as
# 1 ] public function EnterpriseContract():EnterpriseWorkContract {
#
# 2 ] public function ContractGrade():Domain.Employment.Grade.Grade {
#
# 3 ] public function PersonDisplayText(dataContext:DataContext):String {
#
# 4 ] public function PostingDisplayText(dataContext:DataContext):String {
#
# 5 ] public function OrgUnitDisplayText(dataContext:DataContext):String {
#
# 6 ] public function PostDisplayText(dataContext:DataContext):String {
#
# 7 ] public function get IsSubstantive():Boolean {return this is SubstantiveWorkContract;}
#
# 8 ] public function get WTE():Number {
#
# 9 ] public function get RoundedWTE():Number {
#
# 10 ] public function get GradeName():String {
#
# 11 ] public function get ContractedTimePerWeek():int{
#
# 12 ] public function get ContractedTimeBasis():Domain.Employment.ContractedTimeBasis{
#
# 13 ] public function get ContractedTimeBasisCaption():String{
#
# 14 ] public function ObtainPrimaryEntityOwningUnit(context:DataContext):PrimaryEntityOwningUnit {
#
# -------------------------------------------------
# 18 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/PersonWorkContractBasicBasicSalary
#
#  PersonWorkContractBasicBasicSalary.inc.as
# -------------------------------------------------
# 19 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/PersonWorkContractBasicSalary
#
#  PersonWorkContractBasicSalary.inc.as
# -------------------------------------------------
# 20 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/PersonWorkContractPayScalePoint
#
#  PersonWorkContractPayScalePoint.inc.as
# -------------------------------------------------
# 21 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/PersonWorkingRestrictionSet
#
#  AddPersonWorkingRestrictionSet.inc.as
# 1 ] override public function CompleteConstruction():void {
#
# 2 ] override public function AddAdditionalCommandXml(commandXml:XML):void {
#
# -------------------------------------------------
# 22 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/PersonWorkingRestrictionSet
#
#  ChangePersonWorkingRestrictionSet.inc.as
# 1 ] override public function CompleteConstruction():void {
#
# 2 ] override public function AddAdditionalCommandXml(commandXml:XML):void {
#
# -------------------------------------------------
# 23 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/PersonWorkingRestrictionSet
#
#  PersonWorkingRestrictionSet.inc.as
# 1 ] public function get GridIcon():Object {
#
# 2 ] override public function DefaultLeaveTime(onDate:Date,dataContext:DataContext):Number{
#
# -------------------------------------------------
# 24 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting
#
#  AddPostingWorkContract.inc.as
# 1 ] override public function CompleteConstruction():void {
#
# 2 ] override public function AddAdditionalCommandXml(commandXml:XML):void {
#
# -------------------------------------------------
# 25 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting
#
#  OverrideSubstantiveWorkContract.inc.as
# 1 ] override public function CompleteConstruction():void {
#
# 2 ] override public function AddAdditionalCommandXml(commandXml:XML):void {
#
# -------------------------------------------------
# 26 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting
#
#  Posting.inc.as
# 1 ] public function get OrgUnit():Domain.Establishment.OrgUnit.OrgUnit {
#
# 2 ] public function get PostTitle():String {
#
# 3 ] public function get PostGradeName():String {
#
# 4 ] public function UnitAndPostDisplayText(dataContext:DataContext):String {
#
# 5 ] public function ApplicableContractClosestToViewDate(dataContext:DataContext):PersonWorkContract {
#
# 6 ] public function ClosestActiveDate(on:Date):Date {
#
# 7 ] public function ApplicableContract(dataContext:DataContext, date:Date=null):PersonWorkContract {
#
# 8 ] public function PayrollName(dataContext:DataContext, date:Date=null):String {
#
# 9 ] public function ContractName(dataContext:DataContext, date:Date=null):String {
#
# 10 ] public function PostingWTE(dataContext:DataContext):Number {
#
# 11 ] public function DefaultNonEffectiveTime(dataContext:DataContext, date:Date=null):Number {
#
# 12 ] public function RoundedPostingWTE(dataContext:DataContext):Number {
#
# 13 ] public function OrgUnitName(dataContext:DataContext, onDate:Date=null):String {
#
# 14 ] public function GradeName(dataContext:DataContext):String {
#
# 15 ] public function Grade(dataContext:DataContext, date:Date=null):Domain.Employment.Grade.Grade {
#
# 16 ] public function get HasUserAccessToAgencyFeatures():Boolean { return ClientProgram.Session.User.HasAccessControlGroup(AccessControlGroup.Feature_AgencyFeatures); }
#
# 17 ] public function get HasUserAccessToNegotiatedRatesFeatures():Boolean { return ClientProgram.Session.User.HasAccessControlGroup(AccessControlGroup.Feature_NegotiatedRates);}
#
# 18 ] public function get IsInAgencyPost():Boolean {return Post.IsInAgencyPost;}
# 19 ] public function get IsInBankOrAgencyPostAndUserHasAccess():Boolean { return (IsInBankPost && HasUserAccessToNegotiatedRatesFeatures) || (IsInAgencyPost && HasUserAccessToAgencyFeatures); }
#
# 20 ] public function get IsNotInAgencyPostOrUserHasNoAccess():Boolean { return !IsInBankOrAgencyPostAndUserHasAccess; }
#
# 21 ] public function get IsInBankPost():Boolean {return Post.IsInBankPost;}
#
# 22 ] public function get IsInTempStaffPost():Boolean {return IsInAgencyPost || IsInBankPost;}
#
# 23 ] public function get IsInSubstantivePost():Boolean {return !IsInTempStaffPost;}
#
# 24 ] public function get IsInAgencyUnit():Boolean {return Post.IsInAgencyUnit;}
#
# 25 ] public function get IsInBankUnit():Boolean {return Post.IsInBankUnit;}
#
# 26 ] public function get IsInCloudStaffUnit():Boolean {return Post.IsInCloudStaffUnit;}
#
# 27 ] public function get IsInTempStaffUnit():Boolean {return IsInAgencyUnit || IsInBankUnit;}
#
# 28 ] public function get IsInSubstantiveUnit():Boolean {return !IsInTempStaffUnit;}
#
# 29 ] public function get IsCurrentOrFuture():Boolean {return ValidTo >= ClientProgram.Session.Today;}
#
# 30 ] public function get IsManageAlternativeTeamsDisabled():Boolean {
#
# 31 ] public function get IsManageAlternativeTeamsEnabledAndUserHasAccess():Boolean {
#
# 32 ] public function ContractedHours(dataContext:DataContext, start:Date, end:Date):Number {
#
# 33 ] public function get IsNotInSubstantivePost():Boolean{
#
# 34 ] public function ContractedMinutes(dataContext:DataContext, start:Date, end:Date):Number {
#
# 35 ] public function ContractedMinutesFrench(dataContext:DataContext, start:Date, end:Date):Number {
#
# 36 ] public function CurrentTeam(context:DataContext):String {
#
# 37 ] public function get GridIcon():Object {
#
# 38 ] public function GridIconIdentifier():String {
#
# 39 ] public function ObtainPostingGridData(context:DataContext):PostingGridData {
#
# 40 ] public function ObtainPrimaryEntityOwningUnit(context:DataContext):PrimaryEntityOwningUnit {
#
# 41 ] public function PersonIconFromPostingGridData(context:DataContext):Object {
#
# 42 ] public function PersonIcon(context:DataContext):Object {
#
# 43 ] public function DeterminePersonIcon(context:DataContext, canTakeCharge:Boolean, isExternal:Boolean):Object {
#
# 44 ] public function IsTrainee(context:DataContext):Boolean {
#
# 45 ] public function DiaryPersonIcon(context:DataContext, isExternal:Boolean):Object {
#
# 46 ] public function GetContractOnDate(context:DataContext, on:Date):PersonWorkContract {
#
# 47 ] public function SummaryInfo(context:DataContext):String {
#
# 48 ] public function SummaryInfoUsingKnownAsField(context:DataContext):String {
#
# 49 ] public function PostAndUnitSummaryInfo(context:DataContext):String
#
# 50 ] public function PersonAndGradeSummaryInfo(context:DataContext, on:Date):String {
#
# 51 ] public function ContractsActiveForPosting(context:DataContext):ArrayCollection {
#
# 52 ] public function WorkingRestrictionSetsActiveForPosting(context:DataContext):ArrayCollection {
#
# 53 ] public function ApplicableWorkingRestrictionSet(dataContext:DataContext, date:Date=null):WorkingRestrictionSet {
#
# 54 ] public function ApplicableEntitlement(dataContext:DataContext, date:Date=null):Entitlement {
#
# 55 ] public function ObtainRosterToolTipInfo(context:DataContext):PostingRosterToolTipInfo {
#
# 56 ] public function ObtainHoursBalance(context:DataContext):HoursBalanceQueryResult {
#
# 57 ] public function ObtainMonthlyAndQuarterlyHoursLeft(context:DataContext):MonthlyAndQuarterlyHoursLeft {
#
# 58 ] public function ObtainHoursPeriodBalances(context:DataContext):HoursPeriodBalances {
#
# 59 ] public function ObtainFinalisationSummary(context:DataContext):FinalisationSummary {
#
# 60 ] public function get IsPosting():Boolean {
#
# 61 ] public function get IsPostingAndUserHasAccess():Boolean {
#
# 62 ] public function NonWorkingDays(context:DataContext, range:DateRange):Array {
#
# 63 ] public function AffectedHoursAccount():HoursAccount {
#
# 64 ] public function ObtainAvailablePostingCandidate(context:DataContext):AvailablePostingCandidate {
#
# 65 ] public function ObtainRosterDiaryEarnedAccrualsResults(context:DataContext):RosterViewEarnedAccrualBalances {
#
# 66 ] public function ObtainShowMatchingCandidatesResult(context:DataContext):ShowMatchingDutiesResult {
#
# 67 ] public function ObtainCandidateAssessmentDetails(context:DataContext):AvailablePostingCandidate {
#
# 68 ] public function ObtainPostingAssessmentDetails(context:DataContext):AvailablePostingCandidate {
#
# 69 ] public function ObtainOverlappingDutyAssignmentsDetails(context:DataContext):OverlappingDutyAssignmentsDetails {
#
# 70 ] public function ObtainPostingChangeImpactSummary(context:DataContext):PostingChangeImpactSummary {
#
# 71 ] public function ObtainDailyStaffingYesterdayTodayTomorrow(context:DataContext):DailyStaffingYesterdayTodayTomorrow {
#
# 72 ] public function ObtainDailyStaffingIncidentPlan(context:DataContext):DailyStaffingIncidentPlan {
#
# 73 ] public function ObtainApplicableCallOutTypes(context:DataContext):ApplicableCallOutType {
#
# 74 ] public function ObtainPatternData(context:DataContext):PatternData {
#
# 75 ] public function AssignmentOrStaffNumber():String {
#
# 76 ] public function get UserCanAddPersonalPatterns():Boolean {
#
# 77 ] public function get UserCanAddPersonalPatternsAndAreNotTemporaryStaff():Boolean {
#
# 78 ] public function ShowExpressRemoveInterestAction(context:DataContext):Boolean{
#
# 79 ] public function AreBothDutiesBankCloudStaffOrAgency(first:Duty, next:Duty):Boolean{
#
# 80 ] public function AreBothDutiesBlockDuties(first:Duty, next:Duty):Boolean{
#
# 81 ] public function get UserCanFinalisePosting():Boolean {
#
# -------------------------------------------------
# 27 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/PostingEndReason
#
#  PostingEndReason.inc.as
# -------------------------------------------------
# 28 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/PostingLink
#
#  PostingLink.inc.as
# 1 ] public function ObtainTraineeMentorAssignmentSummary(context:DataContext):TraineeMentorAssignmentsSummary {
#
# -------------------------------------------------
# 29 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/PostingStartReason
#
#  PostingStartReason.inc.as
# -------------------------------------------------
# 30 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/PostingTeam
#
#  PostingTeam.inc.as
# 1 ] public function get GridIcon():Object {
#
# -------------------------------------------------
# 31 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/PostingType
#
#  PostingType.inc.as
# 1 ] public function get GridIcon():Object {
#
# -------------------------------------------------
# 32 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/PostingWorkContract
#
#  AddPostingWorkContract.inc.as
# 1 ] override public function CompleteConstruction():void {
#
# 2 ] override public function AddAdditionalCommandXml(commandXml:XML):void {
#
# -------------------------------------------------
# 33 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/PostingWorkContract
#
#  PostingWorkContract.inc.as
# 1 ] public function get GridIcon():Object {
#
# -------------------------------------------------
# 34 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/PostingWorkingRestrictionSet
#
#  AddPostingWorkingRestrictionSet.inc.as
# 1 ] override public function CompleteConstruction():void {
#
# 2 ] override public function AddAdditionalCommandXml(commandXml:XML):void {
#
# -------------------------------------------------
# 35 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/PostingWorkingRestrictionSet
#
#  PostingWorkingRestrictionSet.inc.as
# 1 ] public function get GridIcon():Object {
#
# 2 ] override public function DefaultLeaveTime(onDate:Date,dataContext:DataContext):Number{
#
# -------------------------------------------------
# 36 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/SubstantiveWorkContract
#
#  SubstantiveWorkContract.inc.as
# 1 ] public function get GridIcon():Object {
#
# -------------------------------------------------
# 37 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/SubstantiveWorkContractBasicSalary
#
#  SubstantiveWorkContractBasicSalary.inc.as
# -------------------------------------------------
# 38 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Team
#
#  AddTeam.inc.as
# 1 ] override public function CompleteConstruction():void {
#
# 2 ] override public function AddAdditionalCommandXml(commandXml:XML):void {
#
# -------------------------------------------------
# 39 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Team
#
#  ClearTeamDutyAssignments.inc.as
# 1 ] 	override public function CompleteConstruction():void {
#
# -------------------------------------------------
# 40 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Team
#
#  Team.inc.as
# 1 ] public function get GridIcon():Object {
#
# 2 ] public function get RosterSortIndexOrDefault():Number {
#
# 3 ] public function ObtainAssignmentSummaryDataBlock(context:DataContext):AssignmentSummaryInfo {
#
# 4 ] public function get UserCanAddPersonalPatternsAndIsNotTemporaryStaff():Boolean {
#
# -------------------------------------------------
# 41 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/WorkingDirective
#
#  WorkingDirective.inc.as
# 1 ] public function get GridIcon():Object {
#
# -------------------------------------------------
# 42 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/WorkingRestrictionSet
#
#  WorkingRestrictionSet.inc.as
# 1 ] public function get MondayDisplayText():String {
#
# 2 ] public function get TuesdayDisplayText():String {
#
# 3 ] public function get WednesdayDisplayText():String {
#
# 4 ] public function get ThursdayDisplayText():String {
#
# 5 ] public function get FridayDisplayText():String {
#
# 6 ] public function get SaturdayDisplayText():String {
#
# 7 ] public function get SundayDisplayText():String {
#
# 8 ] public function DefaultLeaveForMondayDisplayText(dataContext:DataContext):String {
#
# 9 ] public function DefaultLeaveForTuesdayDisplayText(dataContext:DataContext):String {
#
# 10 ] public function DefaultLeaveForWednesdayDisplayText(dataContext:DataContext):String {
#
# 11 ] public function DefaultLeaveForThursdayDisplayText(dataContext:DataContext):String {
#
# 12 ] public function DefaultLeaveForFridayDisplayText(dataContext:DataContext):String {
#
# 13 ] public function DefaultLeaveForSaturdayDisplayText(dataContext:DataContext):String {
#
# 14 ] public function DefaultLeaveForSundayDisplayText(dataContext:DataContext):String {
#
# 15 ] public function IsWorkingDay(date:Date):Boolean {
#
# 16 ] public function DefaultLeaveTimeAsDate(workMinutes:Number,onDate:Date,dataContext:DataContext):Date{
#
# 17 ] public function DefaultLeaveTime(onDate:Date,dataContext:DataContext):Number{
#
# -------------------------------------------------

# %%
def getListOfFiles(dirName):
    # create a list of file and sub directories 
    # names in the given directory 
    listOfFile = os.listdir(dirName)
    allFiles = list()
    # Iterate over all the entries
    for entry in listOfFile:
        # Create full path
        fullPath = os.path.join(dirName, entry)
        # If entry is a directory then get the list of files in this directory 
        if os.path.isdir(fullPath):
            allFiles = allFiles + getListOfFiles(fullPath)
        else:
            if '.as' in fullPath:
                print(fullPath[fullPath.rfind('/'):])
                allFiles.append(fullPath)
                
    return allFiles

listOfFiles = getListOfFiles(directory)
# print(listOfFiles)
# Out:
# /AlternativePostingTeam\AddAlternativePostingTeam.as
# /AlternativePostingTeam\AlternativePostingTeam.as
# /AlternativePostingTeam\AlternativePostingTeam.inc.as
# /AlternativePostingTeam\DeleteAlternativePostingTeam.as
# /AlternativePostingTeam\UpdateAlternativePostingTeam.as
# /AnnualLeaveFinalisationCheck.as
# /ContractedHoursCap.as
# /ContractedTimeBasis.as
# /ContractType\ContractType.as
# /ContractType\ContractType.inc.as
# /ContractType\CreateContractType.as
# /ContractType\DeleteContractType.as
# /ContractType\ExportContractTypes.as
# /ContractType\ImportContractType.as
# /ContractType\ImportContractTypes.as
# /ContractType\ImportContractTypesFile.as
# /ContractType\UpdateContractType.as
# /Employment.as
# /EmploymentType.as
# /EnterpriseWorkContract\BulkSetEnterpriseWorkContractCost.as
# /EnterpriseWorkContract\CreateEnterpriseWorkContract.as
# /EnterpriseWorkContract\DataLoadEnterpriseContract.as
# /EnterpriseWorkContract\DataLoadEnterpriseContractStructure.as
# /EnterpriseWorkContract\EnterpriseWorkContract.as
# /EnterpriseWorkContract\EnterpriseWorkContract.inc.as
# /EnterpriseWorkContract\ExportEnterpriseWorkContracts.as
# /EnterpriseWorkContract\ImportEnterpriseWorkContract.as
# /EnterpriseWorkContract\ImportEnterpriseWorkContracts.as
# /EnterpriseWorkContract\ImportEnterpriseWorkContractsFile.as
# /EnterpriseWorkContract\UpdateEnterpriseWorkContract.as
# /EnterpriseWorkContract\UpdateEnterpriseWorkContractCost.as
# /GlobalWorkContract\CreateGlobalWorkContract.as
# /GlobalWorkContract\GlobalWorkContract.as
# /GlobalWorkContract\GlobalWorkContract.inc.as
# /GlobalWorkContract\ManageProgrammedActivityCalculationPeriods.as
# /GlobalWorkContract\UpdateGlobalWorkContract.as
# /GlobalWorkingRestrictionSet\AddGlobalWorkingRestrictionSet.as
# /GlobalWorkingRestrictionSet\AddGlobalWorkingRestrictionSet.inc.as
# /GlobalWorkingRestrictionSet\GlobalWorkingRestrictionSet.as
# /GlobalWorkingRestrictionSet\GlobalWorkingRestrictionSet.inc.as
# /GlobalWorkingRestrictionSet\PushChanges.as
# /GlobalWorkingRestrictionSet\PushWorkingRestrictionSet.as
# /GlobalWorkingRestrictionSet\UpdateGlobalWorkingRestrictionSet.as
# /GlobalWorkingRestrictionSet\UpdateGlobalWorkingRestrictionSet.inc.as
# /GlobalWorkingRestrictionSet\UpdateGlobalWorkingRestrictionSetWithNotes.as
# /Grade\AddGradeCompetenceToGrade.as
# /Grade\BulkAddGradeCompetence.as
# /Grade\CreateGrade.as
# /Grade\DataLoadGrade.as
# /Grade\DataLoadGradeStructure.as
# /Grade\DeleteGrade.as
# /Grade\ExportGrades.as
# /Grade\Grade.as
# /Grade\Grade.inc.as
# /Grade\ImportGrade.as
# /Grade\ImportGradeConfigurationFile.as
# /Grade\ImportGrades.as
# /Grade\ImportGradesFile.as
# /Grade\UpdateGrade.as
# /GradeType\CreateGradeType.as
# /GradeType\DataLoadGradeType.as
# /GradeType\DataLoadGradeTypes.as
# /GradeType\DeleteGradeType.as
# /GradeType\ExportGradeTypes.as
# /GradeType\GradeType.as
# /GradeType\GradeType.inc.as
# /GradeType\ImportGradeType.as
# /GradeType\ImportGradeTypes.as
# /GradeType\ImportGradeTypesFile.as
# /GradeType\UpdateGradeType.as
# /GradeTypeCategory\CreateGradeTypeCategory.as
# /GradeTypeCategory\DeleteGradeTypeCategory.as
# /GradeTypeCategory\ExportGradeTypeCategorys.as
# /GradeTypeCategory\GradeTypeCategory.as
# /GradeTypeCategory\GradeTypeCategory.inc.as
# /GradeTypeCategory\ImportGradeTypeCategory.as
# /GradeTypeCategory\ImportGradeTypeCategorys.as
# /GradeTypeCategory\ImportGradeTypeCategorysFile.as
# /GradeTypeCategory\UpdateGradeTypeCategory.as
# /GradeWorkContract\BulkSetCost.as
# /GradeWorkContract\BulkSetGradeWorkContractCost.as
# /GradeWorkContract\CreateGradeWorkContract.as
# /GradeWorkContract\CreateGradeWorkContractFromCloudStaff.as
# /GradeWorkContract\DataLoadGradeContract.as
# /GradeWorkContract\DataLoadGradeContractStructure.as
# /GradeWorkContract\ExportGradeWorkContracts.as
# /GradeWorkContract\GradeWorkContract.as
# /GradeWorkContract\GradeWorkContract.inc.as
# /GradeWorkContract\GradeWorkContractCache.as
# /GradeWorkContract\ImportGradeWorkContract.as
# /GradeWorkContract\ImportGradeWorkContracts.as
# /GradeWorkContract\ImportGradeWorkContractsFile.as
# /GradeWorkContract\SetCost.as
# /GradeWorkContract\UpdateCostForGradeWorkContract.as
# /GradeWorkContract\UpdateGradeWorkContract.as
# /GradeWorkContract\UpdateGradeWorkContractCost.as
# /HoursLeftRequired.as
# /IconSet.as
# /IncidentPlanByUnitSearch.as
# /NegotiatedRateApplicability.as
# /OccGroup\CreateOccGroup.as
# /OccGroup\DeleteOccGroup.as
# /OccGroup\ExportOccGroups.as
# /OccGroup\ImportOccGroup.as
# /OccGroup\ImportOccGroups.as
# /OccGroup\ImportOccGroupsFile.as
# /OccGroup\OccGroup.as
# /OccGroup\OccGroup.inc.as
# /OccGroup\UpdateOccGroup.as
# /OccGroupPersonCategory.as
# /OrgUnitPersonAttachment\AddOrgUnitPersonAttachment.as
# /OrgUnitPersonAttachment\AddOrgUnitPersonAttachment.inc.as
# /OrgUnitPersonAttachment\DeleteOrgUnitPersonAttachment.as
# /OrgUnitPersonAttachment\FinalisePerson.as
# /OrgUnitPersonAttachment\OrgUnitPersonAttachment.as
# /OrgUnitPersonAttachment\OrgUnitPersonAttachment.inc.as
# /OrgUnitPersonAttachment\UpdateOrgUnitPersonAttachment.as
# /PatternAssignmentsForTeam\CreatePatternAssignmentsForTeam.as
# /PatternAssignmentsForTeam\PatternAssignmentsForTeam.as
# /PatternAssignmentsForTeam\PatternAssignmentsForTeam.inc.as
# /PersonEmployment\CreatePersonEmployment.as
# /PersonEmployment\PersonEmployment.as
# /PersonEmployment\PersonEmployment.inc.as
# /PersonWorkContract\BulkSendPersonWorkContractNotification.as
# /PersonWorkContract\ChangePersonWorkContractBasicBasicSalary.as
# /PersonWorkContract\ChangePersonWorkContractBasicSalary.as
# /PersonWorkContract\ChangePersonWorkContractPayScalePoint.as
# /PersonWorkContract\CreatePersonWorkContract.as
# /PersonWorkContract\DataloadPersonWorkContractRate.as
# /PersonWorkContract\DataloadPersonWorkContractRates.as
# /PersonWorkContract\PersonWorkContract.as
# /PersonWorkContract\PersonWorkContract.inc.as
# /PersonWorkContract\RemovePersonWorkContractBasicBasicSalaryChanges.as
# /PersonWorkContract\RemovePersonWorkContractBasicSalaryChanges.as
# /PersonWorkContract\RemovePersonWorkContractPayScalePointChanges.as
# /PersonWorkContract\SendPersonWorkContractNotification.as
# /PersonWorkContract\UpdatePersonWorkContract.as
# /PersonWorkContractBasicBasicSalary\AddPersonWorkContractBasicBasicSalary.as
# /PersonWorkContractBasicBasicSalary\PersonWorkContractBasicBasicSalary.as
# /PersonWorkContractBasicBasicSalary\PersonWorkContractBasicBasicSalary.inc.as
# /PersonWorkContractBasicSalary\AddPersonWorkContractBasicSalary.as
# /PersonWorkContractBasicSalary\PersonWorkContractBasicSalary.as
# /PersonWorkContractBasicSalary\PersonWorkContractBasicSalary.inc.as
# /PersonWorkContractPayScalePoint\AddPersonWorkContractPayScalePoint.as
# /PersonWorkContractPayScalePoint\PersonWorkContractPayScalePoint.as
# /PersonWorkContractPayScalePoint\PersonWorkContractPayScalePoint.inc.as
# /PersonWorkingRestrictionSet\AddPersonWorkingRestrictionSet.inc.as
# /PersonWorkingRestrictionSet\ChangePersonWorkingRestrictionSet.as
# /PersonWorkingRestrictionSet\ChangePersonWorkingRestrictionSet.inc.as
# /PersonWorkingRestrictionSet\CreatePersonWorkingRestrictionSet.as
# /PersonWorkingRestrictionSet\PersonWorkingRestrictionSet.as
# /PersonWorkingRestrictionSet\PersonWorkingRestrictionSet.inc.as
# /PersonWorkingRestrictionSet\UpdatePersonWorkingRestrictionSet.as
# /Posting\AddPosting.as
# /Posting\AddPostingForTempStaffingInterface.as
# /Posting\AddPostingFromCloudStaff.as
# /Posting\AddPostingWorkContract.inc.as
# /Posting\AddPostingWorkingRestrictionSetWithNotes.as
# /Posting\AssessAndBookPersonOnListOfDuties.as
# /Posting\AssignDuties.as
# /Posting\AssignNewWebTimesheetDutyAssignment.as
# /Posting\BulkChangePostingTeam.as
# /Posting\BulkSendPostingNotification.as
# /Posting\ChangePostingEntitlement.as
# /Posting\ChangePostingTeam.as
# /Posting\ClearDutyAssignments.as
# /Posting\CreatePosting.as
# /Posting\DataLoadPosting.as
# /Posting\DataLoadPostings.as
# /Posting\DeletePosting.as
# /Posting\DeletePostingFromCloudStaff.as
# /Posting\EditPosting.as
# /Posting\EditPostingWorkContract.as
# /Posting\EditPostingWorkingRestrictionSet.as
# /Posting\EmployeeRequestForAnnualLeave.as
# /Posting\EmployeeRequestForStudyDay.as
# /Posting\EmployeeRequestForUnavailability.as
# /Posting\EndPosting.as
# /Posting\EOLWebTimesheetAddPersonNonEffectivePeriod.as
# /Posting\ExpressInteresOnBehalfOfWorker.as
# /Posting\FinalisePosting.as
# /Posting\GatewayDataLoadLeaveEntitlementAndAccrualPlanForPosting.as
# /Posting\GatewayDataLoadLeaveEntitlementsAndAccrualPlansForPosting.as
# /Posting\GatewayUpdateOfAccrualPlanForPosting.as
# /Posting\InitialiseHoursBalance.as
# /Posting\ManageAlternativeTeams.as
# /Posting\ManuallyAssignGlobalPattern.as
# /Posting\MovePosting.as
# /Posting\OverrideSubstantiveWorkContract.as
# /Posting\OverrideSubstantiveWorkContract.inc.as
# /Posting\PersistCandidate.as
# /Posting\PersistCandidateConfirmed.as
# /Posting\PersistCandidateUnconfirmed.as
# /Posting\PersistCandidateWithResetToLocal.as
# /Posting\PersistDutyCandidates.as
# /Posting\PersistDutyCandidatesConfirmed.as
# /Posting\PersistDutyCandidatesUnconfirmed.as
# /Posting\Posting.as
# /Posting\Posting.inc.as
# /Posting\PostingAutoRosterRequest.as
# /Posting\ReassignPosting.as
# /Posting\ReassignPostingFromCloudStaff.as
# /Posting\RemoveInteresOnBehalfOfWorker.as
# /Posting\RemoveInteresOnBehalfOfWorkerPosting.as
# /Posting\RemovePostingTeamChanges.as
# /Posting\RemovePostingWorkContract.as
# /Posting\RemovePostingWorkingRestrictionSet.as
# /Posting\SendPostingNotification.as
# /Posting\SnapshotPosting.as
# /Posting\UpdatePosting.as
# /Posting\UpdatePostingForTempStaffingInterface.as
# /Posting\UpdatePostingFromCloudStaff.as
# /PostingEndReason\CreatePostingEndReason.as
# /PostingEndReason\DeletePostingEndReason.as
# /PostingEndReason\PostingEndReason.as
# /PostingEndReason\PostingEndReason.inc.as
# /PostingEndReason\UpdatePostingEndReason.as
# /PostingLink\CreatePostingLink.as
# /PostingLink\DeletePostingLink.as
# /PostingLink\PostingLink.as
# /PostingLink\PostingLink.inc.as
# /PostingLinkType.as
# /PostingStartReason\CreatePostingStartReason.as
# /PostingStartReason\DeletePostingStartReason.as
# /PostingStartReason\PostingStartReason.as
# /PostingStartReason\PostingStartReason.inc.as
# /PostingStartReason\UpdatePostingStartReason.as
# /PostingTeam\AddPostingTeam.as
# /PostingTeam\PostingTeam.as
# /PostingTeam\PostingTeam.inc.as
# /PostingTempStaffRequestFilterSearch.as
# /PostingType\CreatePostingType.as
# /PostingType\DataLoadPostingType.as
# /PostingType\DataLoadPostingTypes.as
# /PostingType\DeletePostingType.as
# /PostingType\ExportPostingTypes.as
# /PostingType\ImportPostingType.as
# /PostingType\ImportPostingTypes.as
# /PostingType\ImportPostingTypesFile.as
# /PostingType\PostingType.as
# /PostingType\PostingType.inc.as
# /PostingType\PostingTypeDataLoad.as
# /PostingType\PostingTypeDataLoads.as
# /PostingType\UpdatePostingType.as
# /PostingWorkContract\AddPostingWorkContract.as
# /PostingWorkContract\AddPostingWorkContract.inc.as
# /PostingWorkContract\BaseUpdatePostingWorkContract.as
# /PostingWorkContract\DeletePostingWorkContract.as
# /PostingWorkContract\PostingWorkContract.as
# /PostingWorkContract\PostingWorkContract.inc.as
# /PostingWorkContract\UpdatePostingWorkContract.as
# /PostingWorkingRestrictionSet\AddPostingWorkingRestrictionSet.as
# /PostingWorkingRestrictionSet\AddPostingWorkingRestrictionSet.inc.as
# /PostingWorkingRestrictionSet\DeletePostingWorkingRestrictionSet.as
# /PostingWorkingRestrictionSet\PostingWorkingRestrictionSet.as
# /PostingWorkingRestrictionSet\PostingWorkingRestrictionSet.inc.as
# /PostingWorkingRestrictionSet\UpdatePostingWorkingRestrictionSet.as
# /PostingWorkingRestrictionSet\UpdatePostingWorkingRestrictionSetWithNotes.as
# /QuarterlyPeriodCalculator.as
# /ReassignPostingContractAction.as
# /RegistrationCategory.as
# /SalaryFrequency.as
# /SubstantiveWorkContract\ChangeSubstantiveWorkContractBasicSalary.as
# /SubstantiveWorkContract\CreateSubstantiveWorkContract.as
# /SubstantiveWorkContract\DeleteSubstantiveWorkContract.as
# /SubstantiveWorkContract\EndSubstantiveWorkContract.as
# /SubstantiveWorkContract\RemoveSubstantiveWorkContractBasicSalaryChanges.as
# /SubstantiveWorkContract\SubstantiveWorkContract.as
# /SubstantiveWorkContract\SubstantiveWorkContract.inc.as
# /SubstantiveWorkContract\UpdateSubstantiveWorkContract.as
# /SubstantiveWorkContractBasicSalary\AddSubstantiveWorkContractBasicSalary.as
# /SubstantiveWorkContractBasicSalary\SubstantiveWorkContractBasicSalary.as
# /SubstantiveWorkContractBasicSalary\SubstantiveWorkContractBasicSalary.inc.as
# /Team\AddTeam.as
# /Team\AddTeam.inc.as
# /Team\ClearTeamDutyAssignments.as
# /Team\ClearTeamDutyAssignments.inc.as
# /Team\DeleteTeam.as
# /Team\EnsureTeamInUnit.as
# /Team\MarkTeamAsAvailableToUse.as
# /Team\MarkTeamAsObsolete.as
# /Team\Team.as
# /Team\Team.inc.as
# /Team\TeamAutoRosterRequest.as
# /Team\UpdateTeam.as
# /Types\AlternativePostingTeamDetail.as
# /Types\AssignedPerson.as
# /Types\CloudStaffPosting.as
# /Types\DailyStaffingIncidentPlan.as
# /Types\DailyStaffingYesterdayTodayTomorrow.as
# /Types\DiaryPersonTeamResource.as
# /Types\EnterpriseWorkContractsList.as
# /Types\GradeTypeNonEffectiveGroupFTE.as
# /Types\GradeTypeNonEffectiveGroupFTEs.as
# /Types\GradeTypeNonEffectiveReasonFTE.as
# /Types\GradeTypeNonEffectiveReasonFTEs.as
# /Types\MonthlyAndQuarterlyHoursLeft.as
# /Types\PeopleAssignedOnShiftsForDay.as
# /Types\PeriodHoursLeft.as
# /Types\PostingGridData.as
# /Types\PostingRosterToolTipActivity.as
# /Types\PostingRosterToolTipAgency.as
# /Types\PostingRosterToolTipCompetence.as
# /Types\PostingRosterToolTipDay.as
# /Types\PostingRosterToolTipInfo.as
# /Types\PushWorkingRestrictionSetExclusions.as
# /Types\TraineeMentorAssignmentsForOrgUnit.as
# /Types\TraineeMentorAssignmentsSummary.as
# /Types\TraineeMentorsAssignments.as
# /WorkerType.as
# /WorkingDirective\CreateWorkingDirective.as
# /WorkingDirective\ExportWorkingDirectives.as
# /WorkingDirective\ImportWorkingDirective.as
# /WorkingDirective\ImportWorkingDirectives.as
# /WorkingDirective\ImportWorkingDirectivesFile.as
# /WorkingDirective\UpdateWorkingDirective.as
# /WorkingDirective\WorkingDirective.as
# /WorkingDirective\WorkingDirective.inc.as
# /WorkingDirectiveAssignModes.as
# /WorkingRestrictionSet\CreateWorkingRestrictionSet.as
# /WorkingRestrictionSet\GatewayDataLoadWorkingRestrictionSet.as
# /WorkingRestrictionSet\GatewayDataLoadWorkingRestrictionSets.as
# /WorkingRestrictionSet\UpdateWorkingRestrictionSet.as
# /WorkingRestrictionSet\WorkingRestrictionSet.as
# /WorkingRestrictionSet\WorkingRestrictionSet.inc.as
# /WTDPeriodType.as

# %%
dirr = 'C:/Users/harshal.jaiswal/Desktop/allocate/HealthRosterReactClient/packages/ClientDomain/src/Employee'
i=1
for subdir, dirs, files in os.walk(dirr):
    for file in files:
        j=1
        with open(os.path.join(subdir,file), "r") as fileHandler:  
            # Read next line
            
            for line in fileHandler:
                
                if 'var' in line:
                    print(i,') ',subdir,'\n\n',colored(file,'blue'))
                    i+=1
                        
                    print('\t',j,']', line.replace('\t',''))
                    j+=1
                   
                    print('-------------------------------------------------')

# %%
dirr = 'C:/Users/harshal.jaiswal/Desktop/allocate/HealthRosterReactClient/packages/ClientDomain/src/Employment'
i=1
for subdir, dirs, files in os.walk(dirr):
    for file in files:
        j=1
        with open(os.path.join(subdir,file), "r") as fileHandler: 
            # Read next line
            
            for line in fileHandler:
                
                if 'public' in line and 'String' in line :
                    print(i,') ',subdir,'\n\n',colored(file,'blue'))
                    i+=1
                        
                    print('\t',j,']', line.replace('\t',''))
                    j+=1
                   
                    print('-------------------------------------------------')
# Out:
# 1 )  C:/Users/harshal.jaiswal/Desktop/allocate/HealthRosterReactClient/packages/ClientDomain/src/Allocation\DutyAssignment
#
#  DutyAssignment.ts
# 	 1 ] public get ActualStarDate():String {
#
# -------------------------------------------------
# 2 )  C:/Users/harshal.jaiswal/Desktop/allocate/HealthRosterReactClient/packages/ClientDomain/src/Allocation\DutyAssignment
#
#  DutyAssignment.ts
# 	 2 ] public get ActualEndDate():String {
#
# -------------------------------------------------
# 3 )  C:/Users/harshal.jaiswal/Desktop/allocate/HealthRosterReactClient/packages/ClientDomain/src/Allocation\DutyAssignment
#
#  DutyAssignment.ts
# 	 3 ] public lastManualClockOutReason(context: DataContext): String {
#
# -------------------------------------------------
# 4 )  C:/Users/harshal.jaiswal/Desktop/allocate/HealthRosterReactClient/packages/ClientDomain/src/Audit\Types
#
#  WorkRateAuditDetailsCore.ts
# 	 1 ] result.addStringAttribute('PublicHolidaySelectionType', this.publicHolidaySelectionType);
#
# -------------------------------------------------
# 5 )  C:/Users/harshal.jaiswal/Desktop/allocate/HealthRosterReactClient/packages/ClientDomain/src/DutyDemand\Duty
#
#  Duty.ts
# 	 1 ] public obtainPreferredPersonsListOnTempStaffRequestAsString(context: DataContext): string {
#
# -------------------------------------------------
# 6 )  C:/Users/harshal.jaiswal/Desktop/allocate/HealthRosterReactClient/packages/ClientDomain/src/Gateway\ExternalAssignment
#
#  CreateExternalAssignmentCore.ts
# 	 1 ] if (this.publicHolidayPaymentPreferenceChanged) result.addStringAttribute('PublicHolidayPaymentPreference', this.publicHolidayPaymentPreference);
#
# -------------------------------------------------
# 7 )  C:/Users/harshal.jaiswal/Desktop/allocate/HealthRosterReactClient/packages/ClientDomain/src/Gateway\ExternalAssignment
#
#  UpdateExternalAssignmentCore.ts
# 	 1 ] if (this.publicHolidayPaymentPreferenceChanged) result.addStringAttribute('PublicHolidayPaymentPreference', this.publicHolidayPaymentPreference);
#
# -------------------------------------------------
# 8 )  C:/Users/harshal.jaiswal/Desktop/allocate/HealthRosterReactClient/packages/ClientDomain/src/Gateway\ExternalAssignmentChange
#
#  CreateExternalAssignmentChangeCore.ts
# 	 1 ] if (this.publicHolidayPaymentPreferenceChanged) result.addStringAttribute('PublicHolidayPaymentPreference', this.publicHolidayPaymentPreference);
#
# -------------------------------------------------
# 9 )  C:/Users/harshal.jaiswal/Desktop/allocate/HealthRosterReactClient/packages/ClientDomain/src/Gateway\ExternalAssignmentChange
#
#  UpdateExternalAssignmentChangeCore.ts
# 	 1 ] if (this.publicHolidayPaymentPreferenceChanged) result.addStringAttribute('PublicHolidayPaymentPreference', this.publicHolidayPaymentPreference);
#
# -------------------------------------------------
# 10 )  C:/Users/harshal.jaiswal/Desktop/allocate/HealthRosterReactClient/packages/ClientDomain/src/Gateway\ExternalPerson
#
#  CreateExternalPersonCore.ts
# 	 1 ] if (this.publicHolidayPaymentPreferenceChanged) result.addStringAttribute('PublicHolidayPaymentPreference', this.publicHolidayPaymentPreference);
#
# -------------------------------------------------
# 11 )  C:/Users/harshal.jaiswal/Desktop/allocate/HealthRosterReactClient/packages/ClientDomain/src/Gateway\ExternalPerson
#
#  UpdateExternalPersonCore.ts
# 	 1 ] if (this.publicHolidayPaymentPreferenceChanged) result.addStringAttribute('PublicHolidayPaymentPreference', this.publicHolidayPaymentPreference);
#
# -------------------------------------------------
# 12 )  C:/Users/harshal.jaiswal/Desktop/allocate/HealthRosterReactClient/packages/ClientDomain/src/Gateway\ExternalStarter
#
#  CreateExternalStarterCore.ts
# 	 1 ] if (this.publicHolidayPaymentPreferenceChanged) result.addStringAttribute('PublicHolidayPaymentPreference', this.publicHolidayPaymentPreference);
#
# -------------------------------------------------
# 13 )  C:/Users/harshal.jaiswal/Desktop/allocate/HealthRosterReactClient/packages/ClientDomain/src/Gateway\ExternalStarter
#
#  UpdateExternalStarterCore.ts
# 	 1 ] if (this.publicHolidayPaymentPreferenceChanged) result.addStringAttribute('PublicHolidayPaymentPreference', this.publicHolidayPaymentPreference);
#
# -------------------------------------------------
# 14 )  C:/Users/harshal.jaiswal/Desktop/allocate/HealthRosterReactClient/packages/ClientDomain/src/Gateway\Types
#
#  GatewayResolutionAuditGridDataCore.ts
# 	 1 ] result.addStringAttribute('PublicHolidayPaymentRefResolver', this.publicHolidayPaymentRefResolver);
#
# -------------------------------------------------
# 15 )  C:/Users/harshal.jaiswal/Desktop/allocate/HealthRosterReactClient/packages/ClientDomain/src/Gateway\Types
#
#  GatewayResolutionAuditGridDataCore.ts
# 	 2 ] result.addStringAttribute('PublicHolidayPaymentRefProcessor', this.publicHolidayPaymentRefProcessor);
#
# -------------------------------------------------
# 16 )  C:/Users/harshal.jaiswal/Desktop/allocate/HealthRosterReactClient/packages/ClientDomain/src/People
#
#  PersonAttributeValueType.ts
# 	 1 ] public static readonly StringValue: PersonAttributeValueType = new PersonAttributeValueType("StringValue", 2, () => PersonAttributeValueTypeTerms.StringValue);
#
# -------------------------------------------------
# 17 )  C:/Users/harshal.jaiswal/Desktop/allocate/HealthRosterReactClient/packages/ClientDomain/src/People
#
#  PersonAttributeValueType.ts
# 	 2 ] public static readonly values: PersonAttributeValueType[] = [PersonAttributeValueType.BooleanValue, PersonAttributeValueType.NumericalValue, PersonAttributeValueType.StringValue];
#
# -------------------------------------------------
# 18 )  C:/Users/harshal.jaiswal/Desktop/allocate/HealthRosterReactClient/packages/ClientDomain/src/ReferenceData\Setting
#
#  SettingValues.ts
# 	 1 ] public parse(settingValue: String): Object {
#
# -------------------------------------------------
# 19 )  C:/Users/harshal.jaiswal/Desktop/allocate/HealthRosterReactClient/packages/ClientDomain/src/RosterDemand\Types
#
#  StringValueCore.ts
# 	 1 ] public copy(): ComplexType {return new StringValueCore(this);}
#
# -------------------------------------------------
# 20 )  C:/Users/harshal.jaiswal/Desktop/allocate/HealthRosterReactClient/packages/ClientDomain/src/RosterDemand\Types
#
#  StringValueCore.ts
# 	 2 ] public asXml(elementName:string = 'StringValue'):XmlElement {
#
# -------------------------------------------------

# %%
directory='C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/'

i=1
for subdir, dirs, files in os.walk(directory):
    for file in files:
        j=1
        with open(os.path.join(subdir,file), "r") as fileHandler: 
            # Read next line
            
            for line in fileHandler:
                
                if 'public' in line and 'return' in line and ';' in line:
                    print(i,') ',subdir,'\n\n',colored(file,'blue'))
                    i+=1
                        
                    print('\t',j,']', line.replace('\t',''))
                    j+=1
                   
                    print('-------------------------------------------------')
# Out:
# 1 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPosting.as
# 	 1 ] public function get GradeWorkContract():Domain.Employment.GradeWorkContract.GradeWorkContract {return gradeWorkContract;}
#
# -------------------------------------------------
# 2 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPosting.as
# 	 2 ] public function get ContractedTime():Number {return contractedTime;}
#
# -------------------------------------------------
# 3 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPosting.as
# 	 3 ] public function get WTDOptOut():Boolean {return wTDOptOut;}
#
# -------------------------------------------------
# 4 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPosting.as
# 	 4 ] public function get UseContractedTimeFromGradeWorkContract():Boolean {return useContractedTimeFromGradeWorkContract;}
#
# -------------------------------------------------
# 5 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPosting.as
# 	 5 ] public function get DefaultNonEffectiveTime():Number {return defaultNonEffectiveTime;}
#
# -------------------------------------------------
# 6 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPosting.as
# 	 6 ] public function get UseDefaultNonEffectiveTimeFromGradeWorkContract():Boolean {return useDefaultNonEffectiveTimeFromGradeWorkContract;}
#
# -------------------------------------------------
# 7 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPosting.as
# 	 7 ] public function get InitialNote():String {return initialNote;}
#
# -------------------------------------------------
# 8 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPosting.as
# 	 8 ] public function get ContractType():Domain.Employment.ContractType.ContractType {return contractType;}
#
# -------------------------------------------------
# 9 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPosting.as
# 	 9 ] public function get Amount():Number {return amount;}
#
# -------------------------------------------------
# 10 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPosting.as
# 	 10 ] public function get BasicSalaryFrequency():Domain.Employment.SalaryFrequency {return basicSalaryFrequency;}
#
# -------------------------------------------------
# 11 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPosting.as
# 	 11 ] public function get PayScalePoint():Domain.Costs.PayScalePoint.PayScalePoint {return payScalePoint;}
#
# -------------------------------------------------
# 12 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPosting.as
# 	 12 ] public function get HoursPeriodConfiguration():Domain.Accounts.HoursPeriodConfiguration.HoursPeriodConfiguration {return hoursPeriodConfiguration;}
#
# -------------------------------------------------
# 13 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPosting.as
# 	 13 ] public function get UseHoursPeriodConfigurationStartDate():Boolean {return useHoursPeriodConfigurationStartDate;}
#
# -------------------------------------------------
# 14 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPosting.as
# 	 14 ] public function get GatewayInfo():Domain.Gateway.Types.GatewayChangeAuditSupportingInfo {return gatewayInfo;}
#
# -------------------------------------------------
# 15 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPostingForTempStaffingInterface.as
# 	 1 ] public function get AssignmentNumber():String {return assignmentNumber;}
#
# -------------------------------------------------
# 16 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPostingForTempStaffingInterface.as
# 	 2 ] public function get ValidFrom():Date {return validFrom;}
#
# -------------------------------------------------
# 17 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPostingForTempStaffingInterface.as
# 	 3 ] public function get ValidTo():Date {return validTo;}
#
# -------------------------------------------------
# 18 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPostingForTempStaffingInterface.as
# 	 4 ] public function get WTDOptOut():Boolean {return wTDOptOut;}
#
# -------------------------------------------------
# 19 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPostingForTempStaffingInterface.as
# 	 5 ] public function get Person():Domain.People.Person.Person {return person;}
#
# -------------------------------------------------
# 20 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPostingForTempStaffingInterface.as
# 	 6 ] public function get Grade():Domain.Employment.Grade.Grade {return grade;}
#
# -------------------------------------------------
# 21 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPostingForTempStaffingInterface.as
# 	 7 ] public function get EnterpriseWorkContract():Domain.Employment.EnterpriseWorkContract.EnterpriseWorkContract {return enterpriseWorkContract;}
#
# -------------------------------------------------
# 22 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPostingForTempStaffingInterface.as
# 	 8 ] public function get OrgUnit():Domain.Establishment.OrgUnit.OrgUnit {return orgUnit;}
#
# -------------------------------------------------
# 23 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPostingForTempStaffingInterface.as
# 	 9 ] public function get PostingEndReason():Domain.Employment.PostingEndReason.PostingEndReason {return postingEndReason;}
#
# -------------------------------------------------
# 24 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPostingFromCloudStaff.as
# 	 1 ] public function get CloudStaffId():String {return cloudStaffId;}
#
# -------------------------------------------------
# 25 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPostingFromCloudStaff.as
# 	 2 ] public function get AssignmentNumber():String {return assignmentNumber;}
#
# -------------------------------------------------
# 26 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPostingFromCloudStaff.as
# 	 3 ] public function get ValidFrom():Date {return validFrom;}
#
# -------------------------------------------------
# 27 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPostingFromCloudStaff.as
# 	 4 ] public function get ValidTo():Date {return validTo;}
#
# -------------------------------------------------
# 28 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPostingFromCloudStaff.as
# 	 5 ] public function get Person():Domain.People.Person.Person {return person;}
#
# -------------------------------------------------
# 29 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPostingFromCloudStaff.as
# 	 6 ] public function get GradeWorkContract():Domain.Employment.GradeWorkContract.GradeWorkContract {return gradeWorkContract;}
#
# -------------------------------------------------
# 30 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPostingFromCloudStaff.as
# 	 7 ] public function get OrgUnit():Domain.Establishment.OrgUnit.OrgUnit {return orgUnit;}
#
# -------------------------------------------------
# 31 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPostingFromCloudStaff.as
# 	 8 ] public function get OrgUnitTrustHost():Domain.Establishment.OrgUnit.OrgUnit {return orgUnitTrustHost;}
#
# -------------------------------------------------
# 32 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPostingWorkingRestrictionSetWithNotes.as
# 	 1 ] public function get Comments():String {return comments;}
#
# -------------------------------------------------
# 33 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPostingWorkingRestrictionSetWithNotes.as
# 	 2 ] public function get AddPostingWorkingRestrictionSetCommand():AddPostingWorkingRestrictionSet {return addPostingWorkingRestrictionSet;}
#
# -------------------------------------------------
# 34 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AddPostingWorkingRestrictionSetWithNotes.as
# 	 3 ] public function get Entity():Posting {return entity as Posting;}
#
# -------------------------------------------------
# 35 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AssessAndBookPersonOnListOfDuties.as
# 	 1 ] public function get Duties():Array {return ResolveReferences(duties);}
#
# -------------------------------------------------
# 36 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AssessAndBookPersonOnListOfDuties.as
# 	 2 ] public function get ConfirmationStatus():Domain.TempStaffing.TempStaffConfirmationStatus {return confirmationStatus;}
#
# -------------------------------------------------
# 37 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AssessAndBookPersonOnListOfDuties.as
# 	 3 ] public function get IsInformed():Boolean {return isInformed;}
#
# -------------------------------------------------
# 38 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AssessAndBookPersonOnListOfDuties.as
# 	 4 ] public function get Entity():Posting {return entity as Posting;}
#
# -------------------------------------------------
# 39 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AssignDuties.as
# 	 1 ] public function get Dutys():Array {return ResolveReferences(dutys);}
#
# -------------------------------------------------
# 40 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AssignDuties.as
# 	 2 ] public function get AsRequest():Boolean {return asRequest;}
#
# -------------------------------------------------
# 41 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AssignDuties.as
# 	 3 ] public function get CreateCancelledAssignmentsWhenOverlappingUnavailabilities():Boolean {return createCancelledAssignmentsWhenOverlappingUnavailabilities;}
#
# -------------------------------------------------
# 42 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AssignDuties.as
# 	 4 ] public function get Entity():Posting {return entity as Posting;}
#
# -------------------------------------------------
# 43 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AssignNewWebTimesheetDutyAssignment.as
# 	 1 ] public function get Shift():Domain.RosterDemand.Shift.Shift {return shift;}
#
# -------------------------------------------------
# 44 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AssignNewWebTimesheetDutyAssignment.as
# 	 2 ] public function get On():Date {return on;}
#
# -------------------------------------------------
# 45 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AssignNewWebTimesheetDutyAssignment.as
# 	 3 ] public function get Start():Date {return start;}
#
# -------------------------------------------------
# 46 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AssignNewWebTimesheetDutyAssignment.as
# 	 4 ] public function get End():Date {return end;}
#
# -------------------------------------------------
# 47 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AssignNewWebTimesheetDutyAssignment.as
# 	 5 ] public function get Comments():String {return comments;}
#
# -------------------------------------------------
# 48 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  AssignNewWebTimesheetDutyAssignment.as
# 	 6 ] public function get Entity():Posting {return entity as Posting;}
#
# -------------------------------------------------
# 49 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  ChangePostingEntitlement.as
# 	 1 ] public function get Entitlement():Domain.Accounts.Entitlement.Entitlement {return entitlement;}
#
# -------------------------------------------------
# 50 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  ChangePostingEntitlement.as
# 	 2 ] public function get EntitlementBasis():Domain.Accounts.EntitlementBasis {return entitlementBasis;}
#
# -------------------------------------------------
# 51 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  ChangePostingEntitlement.as
# 	 3 ] public function get EntitlementUnits():Domain.Accounts.EntitlementUnits {return entitlementUnits;}
#
# -------------------------------------------------
# 52 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  ChangePostingEntitlement.as
# 	 4 ] public function get Minutes():Number {return minutes;}
#
# -------------------------------------------------
# 53 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  ChangePostingEntitlement.as
# 	 5 ] public function get Days():Number {return days;}
#
# -------------------------------------------------
# 54 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  ChangePostingEntitlement.as
# 	 6 ] public function get BaseMinutes():Number {return baseMinutes;}
#
# -------------------------------------------------
# 55 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  ChangePostingEntitlement.as
# 	 7 ] public function get BaseDays():Number {return baseDays;}
#
# -------------------------------------------------
# 56 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  ChangePostingEntitlement.as
# 	 8 ] public function get CarryForwardMinutes():Number {return carryForwardMinutes;}
#
# -------------------------------------------------
# 57 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  ChangePostingEntitlement.as
# 	 9 ] public function get CarryForwardDays():Number {return carryForwardDays;}
#
# -------------------------------------------------
# 58 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  ChangePostingEntitlement.as
# 	 10 ] public function get LieuMinutes():Number {return lieuMinutes;}
#
# -------------------------------------------------
# 59 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  ChangePostingEntitlement.as
# 	 11 ] public function get LieuDays():Number {return lieuDays;}
#
# -------------------------------------------------
# 60 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  ChangePostingEntitlement.as
# 	 12 ] public function get ContinuousServiceMinutes():Number {return continuousServiceMinutes;}
#
# -------------------------------------------------
# 61 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  ChangePostingEntitlement.as
# 	 13 ] public function get ContinuousServiceDays():Number {return continuousServiceDays;}
#
# -------------------------------------------------
# 62 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  ChangePostingEntitlement.as
# 	 14 ] public function get EffectiveFrom():Date {return effectiveFrom;}
#
# -------------------------------------------------
# 63 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  ChangePostingEntitlement.as
# 	 15 ] public function get EntitlementType():Domain.Accounts.EntitlementType.EntitlementType {return entitlementType;}
#
# -------------------------------------------------
# 64 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  ChangePostingEntitlement.as
# 	 16 ] public function get EffectiveTo():Date {return effectiveTo;}
#
# -------------------------------------------------
# 65 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  ChangePostingEntitlement.as
# 	 17 ] public function get Entity():Posting {return entity as Posting;}
#
# -------------------------------------------------
# 66 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  ChangePostingTeam.as
# 	 1 ] public function get Entity():Posting {return entity as Posting;}
#
# -------------------------------------------------
# 67 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  ChangePostingTeam.as
# 	 2 ] public function get Team():Domain.Employment.Team.Team {return team;}
#
# -------------------------------------------------
# 68 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  ClearDutyAssignments.as
# 	 1 ] public function get From():Date {return from;}
#
# -------------------------------------------------
# 69 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  ClearDutyAssignments.as
# 	 2 ] public function get To():Date {return to;}
#
# -------------------------------------------------
# 70 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  ClearDutyAssignments.as
# 	 3 ] public function get Entity():Posting {return entity as Posting;}
#
# -------------------------------------------------
# 71 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  CreatePosting.as
# 	 1 ] public override function get XmlElementNameWhenEmbedded():String {return "Posting";}
#
# -------------------------------------------------
# 72 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  CreatePosting.as
# 	 2 ] public function get ExternalReference():String {return externalReference;}
#
# -------------------------------------------------
# 73 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  CreatePosting.as
# 	 3 ] public function get IsPrimary():Boolean {return isPrimary;}
#
# -------------------------------------------------
# 74 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  CreatePosting.as
# 	 4 ] public function get AssignmentNumber():String {return assignmentNumber;}
#
# -------------------------------------------------
# 75 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  CreatePosting.as
# 	 5 ] public function get RosterSortIndex():Number {return rosterSortIndex;}
#
# -------------------------------------------------
# 76 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  CreatePosting.as
# 	 6 ] public function get CloudStaffId():String {return cloudStaffId;}
#
# -------------------------------------------------
# 77 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  CreatePosting.as
# 	 7 ] public function get ReassignedFrom():Number {return reassignedFrom;}
#
# -------------------------------------------------
# 78 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  CreatePosting.as
# 	 8 ] public function get ValidFrom():Date {return validFrom;}
#
# -------------------------------------------------
# 79 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  CreatePosting.as
# 	 9 ] public function get ValidTo():Date {return validTo;}
#
# -------------------------------------------------
# 80 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  CreatePosting.as
# 	 10 ] public function get AnnualLeaveAccrualPlan():Domain.NonEffectives.AnnualLeaveAccrualPlan.AnnualLeaveAccrualPlan {return annualLeaveAccrualPlan;}
#
# -------------------------------------------------
# 81 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  CreatePosting.as
# 	 11 ] public function get PublicHolidayPaymentPreference():Domain.People.PublicHolidayPaymentPreference.PublicHolidayPaymentPreference {return publicHolidayPaymentPreference;}
#
# -------------------------------------------------
# 82 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  CreatePosting.as
# 	 12 ] public function get PostingStartReason():Domain.Employment.PostingStartReason.PostingStartReason {return postingStartReason;}
#
# -------------------------------------------------
# 83 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  CreatePosting.as
# 	 13 ] public function get PostingEndReason():Domain.Employment.PostingEndReason.PostingEndReason {return postingEndReason;}
#
# -------------------------------------------------
# 84 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  CreatePosting.as
# 	 14 ] public function get PostingType():Domain.Employment.PostingType.PostingType {return postingType;}
#
# -------------------------------------------------
# 85 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  CreatePosting.as
# 	 15 ] public function get OrgUnitTrustHost():Domain.Establishment.OrgUnit.OrgUnit {return orgUnitTrustHost;}
#
# -------------------------------------------------
# 86 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  CreatePosting.as
# 	 16 ] public function get PersonEmployment():Domain.Employment.PersonEmployment.PersonEmployment {return personEmployment;}
#
# -------------------------------------------------
# 87 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  CreatePosting.as
# 	 17 ] public function get Person():Domain.People.Person.Person {return person;}
#
# -------------------------------------------------
# 88 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  CreatePosting.as
# 	 18 ] public function get NoteGroup():Domain.Comms.NoteGroup.NoteGroup {return noteGroup;}
#
# -------------------------------------------------
# 89 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  CreatePosting.as
# 	 19 ] public function get PostingsForPost():Domain.Establishment.PostingsForPost.PostingsForPost {return postingsForPost;}
#
# -------------------------------------------------
# 90 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  CreatePosting.as
# 	 20 ] public function get Post():Domain.Establishment.Post.Post {return post;}
#
# -------------------------------------------------
# 91 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  CreatePosting.as
# 	 21 ] public function get Teams():Array {return teams;} //Array<AddPostingTeam>
#
# -------------------------------------------------
# 92 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  CreatePosting.as
# 	 22 ] public function get InitialTeam():AddPostingTeam {return teams[0];}
#
# -------------------------------------------------
# 93 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  CreatePosting.as
# 	 23 ] public function get AlternativePostingTeams():Array {return alternativePostingTeams;} //Array<AddAlternativePostingTeam>
#
# -------------------------------------------------
# 94 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  CreatePosting.as
# 	 24 ] public function get PostingWorkContract():AddPostingWorkContract {return postingWorkContract;}
#
# -------------------------------------------------
# 95 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  CreatePosting.as
# 	 25 ] public function get PostingWorkingRestrictionSet():AddPostingWorkingRestrictionSet {return postingWorkingRestrictionSet;}
#
# -------------------------------------------------
# 96 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  DataLoadPosting.as
# 	 1 ] public function get StaffNumber():String {return staffNumber;}
#
# -------------------------------------------------
# 97 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  DataLoadPosting.as
# 	 2 ] public function get FirstName():String {return firstName;}
#
# -------------------------------------------------
# 98 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  DataLoadPosting.as
# 	 3 ] public function get LastName():String {return lastName;}
#
# -------------------------------------------------
# 99 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  DataLoadPosting.as
# 	 4 ] public function get Hospital():String {return hospital;}
#
# -------------------------------------------------
# 100 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  DataLoadPosting.as
# 	 5 ] public function get Unit():String {return unit;}
#
# -------------------------------------------------
# 101 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  DataLoadPosting.as
# 	 6 ] public function get StartDate():String {return startDate;}
#
# -------------------------------------------------
# 102 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  DataLoadPosting.as
# 	 7 ] public function get EndDate():String {return endDate;}
#
# -------------------------------------------------
# 103 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  DataLoadPosting.as
# 	 8 ] public function get Team():String {return team;}
#
# -------------------------------------------------
# 104 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  DataLoadPosting.as
# 	 9 ] public function get AssignmentNumber():String {return assignmentNumber;}
#
# -------------------------------------------------
# 105 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  DataLoadPosting.as
# 	 10 ] public function get AssignmentType():String {return assignmentType;}
#
# -------------------------------------------------
# 106 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  DataLoadPostings.as
# 	 1 ] public function get Postings():Array {return postings;}
#
# -------------------------------------------------
# 107 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  DeletePosting.as
# 	 1 ] public function get Entity():Posting {return entity as Posting;}
#
# -------------------------------------------------
# 108 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  DeletePostingFromCloudStaff.as
# 	 1 ] public function get Entity():Posting {return entity as Posting;}
#
# -------------------------------------------------
# 109 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPosting.as
# 	 1 ] public function get HoursPeriodConfiguration():Domain.Accounts.HoursPeriodConfiguration.HoursPeriodConfiguration {return hoursPeriodConfiguration;}
#
# -------------------------------------------------
# 110 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPosting.as
# 	 2 ] public function get UseHoursPeriodConfigurationStartDate():Boolean {return useHoursPeriodConfigurationStartDate;}
#
# -------------------------------------------------
# 111 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkContract.as
# 	 1 ] public function get GradeWorkContract():Domain.Employment.GradeWorkContract.GradeWorkContract {return gradeWorkContract;}
#
# -------------------------------------------------
# 112 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkContract.as
# 	 2 ] public function get ContractedTime():Number {return contractedTime;}
#
# -------------------------------------------------
# 113 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkContract.as
# 	 3 ] public function get DefaultNonEffectiveTime():Number {return defaultNonEffectiveTime;}
#
# -------------------------------------------------
# 114 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkContract.as
# 	 4 ] public function get ContractType():Domain.Employment.ContractType.ContractType {return contractType;}
#
# -------------------------------------------------
# 115 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkContract.as
# 	 5 ] public function get WTDOptOut():Boolean {return wTDOptOut;}
#
# -------------------------------------------------
# 116 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkContract.as
# 	 6 ] public function get PayScalePoint():Domain.Costs.PayScalePoint.PayScalePoint {return payScalePoint;}
#
# -------------------------------------------------
# 117 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkContract.as
# 	 7 ] public function get Entity():Posting {return entity as Posting;}
#
# -------------------------------------------------
# 118 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 1 ] public function get NumDaysPerWeek():Number {return numDaysPerWeek;}
#
# -------------------------------------------------
# 119 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 2 ] public function get MaxConsecutiveDays():Number {return maxConsecutiveDays;}
#
# -------------------------------------------------
# 120 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 3 ] public function get MaxConsecutiveDaysRequested():Number {return maxConsecutiveDaysRequested;}
#
# -------------------------------------------------
# 121 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 4 ] public function get MaxDaysPerWeek():Number {return maxDaysPerWeek;}
#
# -------------------------------------------------
# 122 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 5 ] public function get MaxWorkTimePerDay():Number {return maxWorkTimePerDay;}
#
# -------------------------------------------------
# 123 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 6 ] public function get MaxShiftsPerDay():Number {return maxShiftsPerDay;}
#
# -------------------------------------------------
# 124 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 7 ] public function get MaxShiftsPerWeek():Number {return maxShiftsPerWeek;}
#
# -------------------------------------------------
# 125 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 8 ] public function get PermittedOvertimePerDay():Number {return permittedOvertimePerDay;}
#
# -------------------------------------------------
# 126 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 9 ] public function get PermittedOvertimePerWeek():Number {return permittedOvertimePerWeek;}
#
# -------------------------------------------------
# 127 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 10 ] public function get MinBreakBetweenShifts():Number {return minBreakBetweenShifts;}
#
# -------------------------------------------------
# 128 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 11 ] public function get AdditionalHoursAfterHoursPerWeek():Number {return additionalHoursAfterHoursPerWeek;}
#
# -------------------------------------------------
# 129 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 12 ] public function get MonStart():Date {return monStart;}
#
# -------------------------------------------------
# 130 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 13 ] public function get MonEnd():Date {return monEnd;}
# -------------------------------------------------
# 131 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 14 ] public function get TueStart():Date {return tueStart;}
#
# -------------------------------------------------
# 132 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 15 ] public function get TueEnd():Date {return tueEnd;}
#
# -------------------------------------------------
# 133 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 16 ] public function get WedStart():Date {return wedStart;}
#
# -------------------------------------------------
# 134 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 17 ] public function get WedEnd():Date {return wedEnd;}
#
# -------------------------------------------------
# 135 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 18 ] public function get ThursStart():Date {return thursStart;}
#
# -------------------------------------------------
# 136 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 19 ] public function get ThursEnd():Date {return thursEnd;}
#
# -------------------------------------------------
# 137 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 20 ] public function get FriStart():Date {return friStart;}
#
# -------------------------------------------------
# 138 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 21 ] public function get FriEnd():Date {return friEnd;}
#
# -------------------------------------------------
# 139 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 22 ] public function get SatStart():Date {return satStart;}
#
# -------------------------------------------------
# 140 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 23 ] public function get SatEnd():Date {return satEnd;}
#
# -------------------------------------------------
# 141 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 24 ] public function get SunStart():Date {return sunStart;}
#
# -------------------------------------------------
# 142 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 25 ] public function get SunEnd():Date {return sunEnd;}
#
# -------------------------------------------------
# 143 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 26 ] public function get WTDDayStart():Date {return wTDDayStart;}
#
# -------------------------------------------------
# 144 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 27 ] public function get WTDWeekDayStart():Number {return wTDWeekDayStart;}
#
# -------------------------------------------------
# 145 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 28 ] public function get WTDWeekTimeStart():Date {return wTDWeekTimeStart;}
#
# -------------------------------------------------
# 146 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 29 ] public function get UseHoursOfWorkForDefaultingLeave():Boolean {return useHoursOfWorkForDefaultingLeave;}
#
# -------------------------------------------------
# 147 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 30 ] public function get DefaultLeaveForMon():Date {return defaultLeaveForMon;}
#
# -------------------------------------------------
# 148 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 31 ] public function get DefaultLeaveForTue():Date {return defaultLeaveForTue;}
#
# -------------------------------------------------
# 149 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 32 ] public function get DefaultLeaveForWed():Date {return defaultLeaveForWed;}
#
# -------------------------------------------------
# 150 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 33 ] public function get DefaultLeaveForThurs():Date {return defaultLeaveForThurs;}
#
# -------------------------------------------------
# 151 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 34 ] public function get DefaultLeaveForFri():Date {return defaultLeaveForFri;}
#
# -------------------------------------------------
# 152 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  EditPostingWorkingRestrictionSet.as
# 	 35 ] public function get DefaultLeaveForSat():Date {return defaultLeaveForSat;}
#
# ...
# 371 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  ReassignPostingFromCloudStaff.as
# 	 10 ] public function get ContractedTime():Number {return contractedTime;}
#
# -------------------------------------------------
# 372 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  ReassignPostingFromCloudStaff.as
# 	 11 ] public function get ContractAction():Domain.Employment.ReassignPostingContractAction {return contractAction;}
#
# -------------------------------------------------
# 373 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  ReassignPostingFromCloudStaff.as
# 	 12 ] public function get NewPostingCloudStaffId():String {return newPostingCloudStaffId;}
#
# -------------------------------------------------
# 374 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  ReassignPostingFromCloudStaff.as
# 	 13 ] public function get ReturnToCurrentPostingCloudStaffId():String {return returnToCurrentPostingCloudStaffId;}
#
# -------------------------------------------------
# 375 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  ReassignPostingFromCloudStaff.as
# 	 14 ] public function get Entity():Posting {return entity as Posting;}
#
# -------------------------------------------------
# 376 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  RemoveInteresOnBehalfOfWorker.as
# 	 1 ] public function get AvailablePostingCandidate():Domain.DutyDemand.Types.AvailablePostingCandidate {return availablePostingCandidate;}
#
# -------------------------------------------------
# 377 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  RemoveInteresOnBehalfOfWorkerPosting.as
# 	 1 ] public function get AvailablePostingCandidate():Domain.DutyDemand.Types.AvailablePostingCandidate {return availablePostingCandidate;}
#
# -------------------------------------------------
# 378 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  RemovePostingTeamChanges.as
# 	 1 ] public function get Entity():Posting {return entity as Posting;}
#
# -------------------------------------------------
# 379 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  RemovePostingTeamChanges.as
# 	 2 ] public function get From():Date {return On;}
#
# -------------------------------------------------
# 380 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  RemovePostingWorkContract.as
# 	 1 ] public function get Entity():Posting {return entity as Posting;}
#
# -------------------------------------------------
# 381 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  RemovePostingWorkingRestrictionSet.as
# 	 1 ] public function get Entity():Posting {return entity as Posting;}
#
# -------------------------------------------------
# 382 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  SendPostingNotification.as
# 	 1 ] public function get To():String {return to;}
#
# -------------------------------------------------
# 383 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  SendPostingNotification.as
# 	 2 ] public function get NotificationDefinition():Domain.Notifications.NotificationDefinition.NotificationDefinition {return notificationDefinition;}
#
# -------------------------------------------------
# 384 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  SendPostingNotification.as
# 	 3 ] public function get SendEmail():Boolean {return sendEmail;}
#
# -------------------------------------------------
# 385 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  SendPostingNotification.as
# 	 4 ] public function get SendSms():Boolean {return sendSms;}
#
# -------------------------------------------------
# 386 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  SendPostingNotification.as
# 	 5 ] public function get OverriddenSmsBody():String {return overriddenSmsBody;}
#
# -------------------------------------------------
# 387 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  SendPostingNotification.as
# 	 6 ] public function get Entity():Posting {return entity as Posting;}
#
# -------------------------------------------------
# 388 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  SnapshotPosting.as
# 	 1 ] public function get From():Date {return from;}
#
# -------------------------------------------------
# 389 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  SnapshotPosting.as
# 	 2 ] public function get To():Date {return to;}
#
# -------------------------------------------------
# 390 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  SnapshotPosting.as
# 	 3 ] public function get Entity():Posting {return entity as Posting;}
#
# -------------------------------------------------
# 391 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  UpdatePosting.as
# 	 1 ] public function get ExternalReference():String {return externalReference;}
#
# -------------------------------------------------
# 392 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  UpdatePosting.as
# 	 2 ] public function get IsPrimary():Boolean {return isPrimary;}
#
# -------------------------------------------------
# 393 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  UpdatePosting.as
# 	 3 ] public function get AssignmentNumber():String {return assignmentNumber;}
#
# -------------------------------------------------
# 394 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  UpdatePosting.as
# 	 4 ] public function get RosterSortIndex():Number {return rosterSortIndex;}
#
# -------------------------------------------------
# 395 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  UpdatePosting.as
# 	 5 ] public function get CloudStaffId():String {return cloudStaffId;}
#
# -------------------------------------------------
# 396 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  UpdatePosting.as
# 	 6 ] public function get ReassignedFrom():Number {return reassignedFrom;}
#
# -------------------------------------------------
# 397 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  UpdatePosting.as
# 	 7 ] public function get ValidFrom():Date {return validFrom;}
#
# -------------------------------------------------
# 398 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  UpdatePosting.as
# 	 8 ] public function get ValidTo():Date {return validTo;}
#
# -------------------------------------------------
# 399 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  UpdatePosting.as
# 	 9 ] public function get AnnualLeaveAccrualPlan():Domain.NonEffectives.AnnualLeaveAccrualPlan.AnnualLeaveAccrualPlan {return annualLeaveAccrualPlan;}
#
# -------------------------------------------------
# 400 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  UpdatePosting.as
# 	 10 ] public function get PublicHolidayPaymentPreference():Domain.People.PublicHolidayPaymentPreference.PublicHolidayPaymentPreference {return publicHolidayPaymentPreference;}
#
# -------------------------------------------------
# 401 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  UpdatePosting.as
# 	 11 ] public function get PostingStartReason():Domain.Employment.PostingStartReason.PostingStartReason {return postingStartReason;}
#
# -------------------------------------------------
# 402 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  UpdatePosting.as
# 	 12 ] public function get PostingEndReason():Domain.Employment.PostingEndReason.PostingEndReason {return postingEndReason;}
#
# -------------------------------------------------
# 403 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  UpdatePosting.as
# 	 13 ] public function get PostingType():Domain.Employment.PostingType.PostingType {return postingType;}
#
# -------------------------------------------------
# 404 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  UpdatePosting.as
# 	 14 ] public function get OrgUnitTrustHost():Domain.Establishment.OrgUnit.OrgUnit {return orgUnitTrustHost;}
#
# -------------------------------------------------
# 405 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  UpdatePosting.as
# 	 15 ] public function get PersonEmployment():Domain.Employment.PersonEmployment.PersonEmployment {return personEmployment;}
#
# -------------------------------------------------
# 406 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  UpdatePosting.as
# 	 16 ] public function get Person():Domain.People.Person.Person {return Posting(entity).Person;}
#
# -------------------------------------------------
# 407 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  UpdatePosting.as
# 	 17 ] public function get NoteGroup():Domain.Comms.NoteGroup.NoteGroup {return Posting(entity).NoteGroup;}
#
# -------------------------------------------------
# 408 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  UpdatePosting.as
# 	 18 ] public function get PostingsForPost():Domain.Establishment.PostingsForPost.PostingsForPost {return Posting(entity).PostingsForPost;}
#
# -------------------------------------------------
# 409 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  UpdatePosting.as
# 	 19 ] public function get Post():Domain.Establishment.Post.Post {return Posting(entity).Post;}
#
# -------------------------------------------------
# 410 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  UpdatePosting.as
# 	 20 ] public function get Entity():Posting {return entity as Posting;}
#
# -------------------------------------------------
# 411 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  UpdatePostingForTempStaffingInterface.as
# 	 1 ] public function get AssignmentNumber():String {return assignmentNumber;}
#
# -------------------------------------------------
# 412 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  UpdatePostingForTempStaffingInterface.as
# 	 2 ] public function get ValidFrom():Date {return validFrom;}
#
# -------------------------------------------------
# 413 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  UpdatePostingForTempStaffingInterface.as
# 	 3 ] public function get ValidTo():Date {return validTo;}
#
# -------------------------------------------------
# 414 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  UpdatePostingForTempStaffingInterface.as
# 	 4 ] public function get WTDOptOut():Boolean {return wTDOptOut;}
#
# -------------------------------------------------
# 415 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  UpdatePostingForTempStaffingInterface.as
# 	 5 ] public function get PostingEndReason():Domain.Employment.PostingEndReason.PostingEndReason {return postingEndReason;}
#
# -------------------------------------------------
# 416 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  UpdatePostingForTempStaffingInterface.as
# 	 6 ] public function get Entity():Posting {return entity as Posting;}
#
# -------------------------------------------------
# 417 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  UpdatePostingFromCloudStaff.as
# 	 1 ] public function get AssignmentNumber():String {return assignmentNumber;}
#
# -------------------------------------------------
# 418 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  UpdatePostingFromCloudStaff.as
# 	 2 ] public function get ValidFrom():Date {return validFrom;}
#
# -------------------------------------------------
# 419 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  UpdatePostingFromCloudStaff.as
# 	 3 ] public function get ValidTo():Date {return validTo;}
#
# -------------------------------------------------
# 420 )  C:/Users/harshal.jaiswal/Desktop/allocate/DevHealthRoster_10_8_3/Products/HealthRoster/Deliverables/ClientDomain/src/Domain/Employment/Posting/
#
#  UpdatePostingFromCloudStaff.as
# 	 4 ] public function get Entity():Posting {return entity as Posting;}
#
# -------------------------------------------------

# %%
import fileinput
import sys
import os 

import re

def replace(file, pattern, subst):
    # Read contents from file as a single string
    file_handle = open(file, 'r')
    file_string = file_handle.read()
    file_handle.close()

    # Use RE package to allow for replacement (also allowing for (multiline) REGEX)
    file_string = file_string.replace(pattern,subst) #(re.sub(pattern, subst, file_string))
#     print('rr',pattern)
    print('hii',subst)
#     print('byy',file_string.replace(pattern,subst))
    # Write contents to file.
    # Using mode 'w' truncates the file.
    file_handle = open(file, 'w')
    file_handle.write(file_string)
    file_handle.close()
    

tryf= 'C:/Users/harshal.jaiswal/Desktop/trial'
dirr = 'C:/Users/harshal.jaiswal/Desktop/allocate/HealthRosterReactClient/packages/ClientDomain/src/Employment'

replace_var ='Number '
replace_by= 'number '
i=1
for subdir, dirs, files in os.walk(dirr):
    for file in files:
        j=1
        with open(os.path.join(subdir,file), "r") as fileHandler: 
            # Read next line
            
            for line in fileHandler:
                
                if replace_var in line and 'public' in line:
                    print(i,') ',subdir,'\n\n',colored(file,'blue'))
                    i+=1
                        
                    print('\t',j,']', line.replace('\t',''))
                    j+=1
#                     replace(os.path.join(subdir,file),line,line.replace(replace_var,replace_by))
                   
                    print('-------------------------------------------------')
# Out:
# 1 )  C:/Users/harshal.jaiswal/Desktop/allocate/HealthRosterReactClient/packages/ClientDomain/src/Employment\Posting
#
#  Posting.ts
# 	 1 ] public contractedHours(dataContext:DataContext, start:Date, end:Date):Number {
#
# hii 	public contractedHours(dataContext:DataContext, start:Date, end:Date):number {
#
# -------------------------------------------------

# %%
import fileinput
import sys
import os 

import re

def replace(file, pattern, subst):
    # Read contents from file as a single string
    file_handle = open(file, 'r')
    file_string = file_handle.read()
    file_handle.close()

    # Use RE package to allow for replacement (also allowing for (multiline) REGEX)
    file_string = file_string.replace(pattern,subst) #(re.sub(pattern, subst, file_string))
#     print('rr',pattern)
    print('hii',subst)
#     print('byy',file_string.replace(pattern,subst))
    # Write contents to file.
    # Using mode 'w' truncates the file.
    file_handle = open(file, 'w')
    file_handle.write(file_string)
    file_handle.close()
    

tryf= 'C:/Users/harshal.jaiswal/Desktop/trial'
dirr = 'C:/Users/harshal.jaiswal/Desktop/allocate/HealthRosterReactClient/packages/ClientDomain/src/Employment'

replace_var ='get '
replace_by= 'number '
i=1
for subdir, dirs, files in os.walk(dirr):
    for file in files:
        j=1
        with open(os.path.join(subdir,file), "r") as fileHandler: 
            # Read next line
            
            for line in fileHandler:
                
                if replace_var in line and 'public' in line:
                    line_temp=line
                    func_name = line[line.index('get ')+4:-1]
                    
                    if not func_name[0].isupper():
                        func_name=func_name[0].upper()+func_name[1:]
                        line_temp =line_temp[:line.index('get ')+4]+func_name+'\n'
                        print('hii',line,line_temp)
                        print(i,') ',subdir,'\n\n',colored(file,'blue'))
                        i+=1

                        print('\t',j,']', line.replace('\t',''))
                        j+=1
#                         replace(os.path.join(subdir,file),line,line_temp)
                        print('-------------------------------------------------')
